# %%
# GeneLab AI/ML AWG RR9 - Digital Twin Project - Data Download and Inspection Scripts
# Version: 2024-03-14

import os
import urllib.request as urlrequest
from urllib.parse import quote
import requests
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 4000) # Modify this value to best fit your screen/editor
pd.set_option('display.max_colwidth', 100) # Use this option to display the full content of columns

from pprint import pprint as pp
from tqdm import tqdm

# %%
# Obtain an overview of the RR9 dataset
data_url = 'https://osdr.nasa.gov/osdr/data/osd/files/255,568,557,583,397,203,194,87'

response = requests.get(data_url)

if response.status_code == 200:
    data = response.json()
    df = pd.json_normalize(data)
else:
    print('Error:', response.status_code)
    df = pd.DataFrame()

print(df.info())
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   hits                         1 non-null      int64
#  1   input                        1 non-null      object
#  2   page_number                  1 non-null      int64
#  3   page_size                    1 non-null      int64
#  4   page_total                   1 non-null      int64
#  5   success                      1 non-null      bool
#  6   total_hits                   1 non-null      int64
#  7   valid_input                  1 non-null      object
#  8   studies.OSD-194.file_count   1 non-null      int64
#  9   studies.OSD-194.study_files  1 non-null      object
#  10  studies.OSD-203.file_count   1 non-null      int64
#  11  studies.OSD-203.study_files  1 non-null      object
#  12  studies.OSD-255.file_count   1 non-null      int64
#  13  studies.OSD-255.study_files  1 non-null      object
#  14  studies.OSD-397.file_count   1 non-null      int64
#  15  studies.OSD-397.study_files  1 non-null      object
#  16  studies.OSD-557.file_count   1 non-null      int64
#  17  studies.OSD-557.study_files  1 non-null      object
#  18  studies.OSD-568.file_count   1 non-null      int64
#  19  studies.OSD-568.study_files  1 non-null      object
#  20  studies.OSD-583.file_count   1 non-null      int64
#  21  studies.OSD-583.study_files  1 non-null      object
#  22  studies.OSD-87.file_count    1 non-null      int64
#  23  studies.OSD-87.study_files   1 non-null      object
# dtypes: bool(1), int64(13), object(10)
# memory usage: 317.0+ bytes
# None
#    hits                           input  page_number  page_size  page_total  success  total_hits                              valid_input  studies.OSD-194.file_count                                                                          studies.OSD-194.study_files  studies.OSD-203.file_count                                                                          studies.OSD-203.study_files  studies.OSD-255.file_count                                                                          studies.OSD-255.study_files  studies.OSD-397.file_count                                                                          studies.OSD-397.study_files  studies.OSD-557.file_count                                                                          studies.OSD-557.study_files  studies.OSD-568.file_count                                                                          studies.OSD-568.study_files  studies.OSD-583.file_count                                                                          studies.OSD-583.study_files  studies.OSD-87.file_count                                                                           studies.OSD-87.study_files
# 0     8  255,568,557,583,397,203,194,87            1         25           1     True           8  [255, 568, 557, 583, 397, 203, 194, 87]                         290  [{'category': 'GeneLab Processed RNA-Seq Files', 'date_created': 1680153389.458, 'date_updated':...                         928  [{'category': 'Study Metadata Files', 'date_created': 1632962673.191, 'date_updated': 1632962673...                         200  [{'category': 'Study Metadata Files', 'date_created': 1679660507.127, 'date_updated': 1679660507...                         276  [{'category': 'Study Metadata Files', 'date_created': 1709959943.366, 'date_updated': 1709959943...                          53  [{'category': 'Study Metadata Files', 'date_created': 1685501268.482, 'date_updated': 1685501268...                          52  [{'category': 'Study Metadata Files', 'date_created': 1707980953.405, 'date_updated': 1707980953...                           3  [{'category': 'Study Metadata Files', 'date_created': 1674874083.645, 'date_updated': 1674874083...                         29  [{'category': 'Study Metadata Files', 'date_created': 1601509296.578, 'date_updated': 1601509296...

# %%
# 1. Examine and Download OSD-255 Study Files (Total file size: 13 MB [incomplete download, only results])

file_list = list(df['studies.OSD-255.study_files'])

# Filter entries within file_list with 'category' containing 'Study Metadata', or 'file_name' containing 'Normalized/Unnormalized'

metadata_files = [file for sublist in file_list for file in sublist if 'Study Metadata' in file['category']]
processed_files = [file for sublist in file_list for file in sublist if 'Normalized' in file['file_name'] or 'Unnormalized' in file['file_name']]

pp(len(metadata_files))
pp(metadata_files)
pp(len(processed_files))
pp(processed_files)

# Download files into perspectively named folders

# 1. Create a directory for the OSD Study
study_folder_name = 'OSD-255'
os.makedirs(os.path.join('data', study_folder_name), exist_ok=True)

# 2. Download files
for file in metadata_files:
    file_url = 'https://osdr.nasa.gov' + file['remote_url']
    file_name = file['file_name']
    file_path = os.path.join('data', study_folder_name, file_name)
    urlrequest.urlretrieve(file_url, file_path)
    # If file is a zip file, extract it
    if file_name.endswith('.zip'):
        os.system(f'unzip -o {file_path} -d {os.path.join("data", study_folder_name, 'metadata')}')
        # Remove the zip file
        os.remove(file_path)

for file in processed_files:
    file_url = 'https://osdr.nasa.gov' + file['remote_url']
    file_name = file['file_name']
    file_path = os.path.join('data', study_folder_name, file_name)
    urlrequest.urlretrieve(file_url, file_path)
# Out:
# 1
# [{'category': 'Study Metadata Files',
#   'date_created': 1679660507.127,
#   'date_updated': 1679660507.127,
#   'file_name': 'OSD-255_metadata_OSD-255-ISA.zip',
#   'file_size': 76712,
#   'organization': 'OSD',
#   'remote_url': '/geode-py/ws/studies/OSD-255/download?source=datamanager&file=OSD-255_metadata_OSD-255-ISA.zip',
#   'restricted': False,
#   'subcategory': '',
#   'subdirectory': '',
#   'visible': True}]
# 3
# [{'category': 'GeneLab Processed RNA-Seq Files',
#   'date_created': 1679660513.821,
#   'date_updated': 1679660513.821,
#   'file_name': 'GLDS-255_rna_seq_STAR_Unnormalized_Counts.csv',
#   'file_size': 3457692,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-255/download?source=datamanager&file=GLDS-255_rna_seq_STAR_Unnormalized_Counts.csv',
#   'restricted': False,
#   'subcategory': 'Raw Counts Tables',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed RNA-Seq Files',
#   'date_created': 1679660513.86,
#   'date_updated': 1679660513.86,
#   'file_name': 'GLDS-255_rna_seq_RSEM_Unnormalized_Counts.csv',
#   'file_size': 3598657,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-255/download?source=datamanager&file=GLDS-255_rna_seq_RSEM_Unnormalized_Counts.csv',
#   'restricted': False,
#   'subcategory': 'Raw Counts Tables',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed RNA-Seq Files',
#   'date_created': 1679660513.897,
#   'date_updated': 1679660513.897,
#   'file_name': 'GLDS-255_rna_seq_Normalized_Counts.csv',
#   'file_size': 6347792,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-255/download?source=datamanager&file=GLDS-255_rna_seq_Normalized_Counts.csv',
#   'restricted': False,
#   'subcategory': 'Normalized Counts Data',
#   'subdirectory': '',
#   'visible': True}]
# Archive:  data/OSD-255/OSD-255_metadata_OSD-255-ISA.zip
#  extracting: data/OSD-255/metadata/a_OSD-255_transcription-profiling_rna-sequencing-(rna-seq)_illumina.txt
#  extracting: data/OSD-255/metadata/s_OSD-255.txt
#  extracting: data/OSD-255/metadata/i_Investigation.txt

# %%
# 2. Examine and Download OSD-568 Study Files (Total file size: 4.0 GB [complete download])

file_list = list(df['studies.OSD-568.study_files'])

#pp(file_list)

# Filter entries within file_list with 'category' containing 'Study Metadata', or 'file_name' containing 'Normalized/Unnormalized'
metadata_files = [file for sublist in file_list for file in sublist if 'Study Metadata' in file['category']]
processed_files = [file for sublist in file_list for file in sublist if 'Immunostaining Microscopy' in file['category']]

pp(len(metadata_files))
pp(metadata_files)
pp(len(processed_files))
pp(processed_files)

# Download files into perspectively named folders

# 1. Create a directory for the OSD Study
study_folder_name = 'OSD-568'
os.makedirs(os.path.join('data', study_folder_name), exist_ok=True)

# 2. Download files
for file in metadata_files:
    file_url = 'https://osdr.nasa.gov' + file['remote_url']
    file_name = file['file_name']
    file_path = os.path.join('data', study_folder_name, file_name)

    # Download the file
    urlrequest.urlretrieve(file_url, file_path)

    # If file is a zip file, extract it
    if file_name.endswith('.zip'):
        os.system(f'unzip -o {file_path} -d {os.path.join("data", study_folder_name, 'metadata')}')
        # Remove the zip file
        os.remove(file_path)

for file in tqdm(processed_files, desc="Downloading and Extracting Files"):
    # Encode the remote_url part to handle spaces and other special characters
    encoded_remote_url = quote(file['remote_url'], safe='/?:&=')
    file_url = 'https://osdr.nasa.gov' + encoded_remote_url
    file_name = file['file_name'].replace(' ', '')
    file_path = os.path.join('data', study_folder_name, file_name)
    
    # Download the file
    urlrequest.urlretrieve(file_url, file_path)
    
    # If file is a zip file, extract it
    if file_name.endswith('.zip'):
        os.system(f'unzip -o {file_path} -d {os.path.join('data', study_folder_name, 'microscopy')}')
        # Remove the zip file
        os.remove(file_path)
# Out:
# 1
# [{'category': 'Study Metadata Files',
#   'date_created': 1707980953.405,
#   'date_updated': 1707980953.405,
#   'file_name': 'OSD-568_metadata_OSD-568-ISA.zip',
#   'file_size': 112402,
#   'organization': 'OSD',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=OSD-568_metadata_OSD-568-ISA.zip',
#   'restricted': False,
#   'subcategory': '',
#   'subdirectory': '',
#   'visible': True}]
# 51
# [{'category': 'Immunostaining Microscopy',
#   'date_created': 1707980953.454,
#   'date_updated': 1707980953.454,
#   'file_name': 'LSDS-5_immunostaining_microscopy_Zo-1tr_TRANSFORMED.csv',
#   'file_size': 303,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_Zo-1tr_TRANSFORMED.csv',
#   'restricted': False,
#   'subcategory': 'Tabular Result Files',
#   'subdirectory': 'ALSDA Transformed Files',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1707980953.504,
#   'date_updated': 1707980953.504,
#   'file_name': 'LSDS-5_immunostaining_microscopy_TUNELtr_TRANSFORMED.csv',
#   'file_size': 1388,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_TUNELtr_TRANSFORMED.csv',
#   'restricted': False,
#   'subcategory': 'Tabular Result Files',
#   'subdirectory': 'ALSDA Transformed Files',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1707980953.554,
#   'date_updated': 1707980953.554,
#   'file_name': 'LSDS-5_immunostaining_microscopy_PECAMtr_TRANSFORMED.csv',
#   'file_size': 278,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_PECAMtr_TRANSFORMED.csv',
#   'restricted': False,
#   'subcategory': 'Tabular Result Files',
#   'subdirectory': 'ALSDA Transformed Files',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1707980953.607,
#   'date_updated': 1707980953.607,
#   'file_name': 'LSDS-5_immunostaining_microscopy_Zo-1tr_SUBMITTED.xlsx',
#   'file_size': 13027,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_Zo-1tr_SUBMITTED.xlsx',
#   'restricted': False,
#   'subcategory': 'Tabular Result Files',
#   'subdirectory': 'Original Submitted',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1707980953.657,
#   'date_updated': 1707980953.657,
#   'file_name': 'LSDS-5_immunostaining_microscopy_TUNELtr_SUBMITTED.xlsx',
#   'file_size': 21519,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_TUNELtr_SUBMITTED.xlsx',
#   'restricted': False,
#   'subcategory': 'Tabular Result Files',
#   'subdirectory': 'Original Submitted',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1707980953.706,
#   'date_updated': 1707980953.706,
#   'file_name': 'LSDS-5_immunostaining_microscopy_PECAMtr_SUBMITTED.xlsx',
#   'file_size': 13319,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_PECAMtr_SUBMITTED.xlsx',
#   'restricted': False,
#   'subcategory': 'Tabular Result Files',
#   'subdirectory': 'Original Submitted',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.019,
#   'date_updated': 1685500662.019,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC19_ Mouse_Eye_ZO.zip',
#   'file_size': 111239455,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC19_ '
#                 'Mouse_Eye_ZO.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.023,
#   'date_updated': 1685500662.023,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC18_ Mouse_Eye_ZO.zip',
#   'file_size': 148284789,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC18_ '
#                 'Mouse_Eye_ZO.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.027,
#   'date_updated': 1685500662.027,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC17_ Mouse_Eye_ZO.zip',
#   'file_size': 133915796,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC17_ '
#                 'Mouse_Eye_ZO.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.031,
#   'date_updated': 1685500662.031,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC16_ Mouse_Eye_ZO.zip',
#   'file_size': 90640150,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC16_ '
#                 'Mouse_Eye_ZO.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.035,
#   'date_updated': 1685500662.035,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC15_ Mouse_Eye_ZO.zip',
#   'file_size': 93731256,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC15_ '
#                 'Mouse_Eye_ZO.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.039,
#   'date_updated': 1685500662.039,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F20_ Mouse_Eye_ZO.zip',
#   'file_size': 158013935,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F20_ '
#                 'Mouse_Eye_ZO.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.043,
#   'date_updated': 1685500662.043,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F19_ Mouse_Eye_ZO.zip',
#   'file_size': 127372004,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F19_ '
#                 'Mouse_Eye_ZO.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.047,
#   'date_updated': 1685500662.047,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F18_ Mouse_Eye_ZO.zip',
#   'file_size': 138680805,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F18_ '
#                 'Mouse_Eye_ZO.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.051,
#   'date_updated': 1685500662.051,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F17_ Mouse_Eye_ZO.zip',
#   'file_size': 103391362,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F17_ '
#                 'Mouse_Eye_ZO.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.056,
#   'date_updated': 1685500662.056,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F16_ Mouse_Eye_ZO.zip',
#   'file_size': 71979214,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F16_ '
#                 'Mouse_Eye_ZO.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.06,
#   'date_updated': 1685500662.06,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F15_ Mouse_Eye_ZO.zip',
#   'file_size': 91983045,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F15_ '
#                 'Mouse_Eye_ZO.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.064,
#   'date_updated': 1685500662.064,
#   'file_name': 'LSDS-5_immunostaining_microscopy_V20_ Mouse_Eye_TUNEL.zip',
#   'file_size': 75526448,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_V20_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.068,
#   'date_updated': 1685500662.068,
#   'file_name': 'LSDS-5_immunostaining_microscopy_V19_ Mouse_Eye_TUNEL.zip',
#   'file_size': 87093221,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_V19_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.072,
#   'date_updated': 1685500662.072,
#   'file_name': 'LSDS-5_immunostaining_microscopy_V18_ Mouse_Eye_TUNEL.zip',
#   'file_size': 95646568,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_V18_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.076,
#   'date_updated': 1685500662.076,
#   'file_name': 'LSDS-5_immunostaining_microscopy_V17_ Mouse_Eye_TUNEL.zip',
#   'file_size': 77117991,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_V17_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.08,
#   'date_updated': 1685500662.08,
#   'file_name': 'LSDS-5_immunostaining_microscopy_V16_ Mouse_Eye_TUNEL.zip',
#   'file_size': 85618206,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_V16_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.085,
#   'date_updated': 1685500662.085,
#   'file_name': 'LSDS-5_immunostaining_microscopy_V15_ Mouse_Eye_TUNEL.zip',
#   'file_size': 111333328,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_V15_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.089,
#   'date_updated': 1685500662.089,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC20_ Mouse_Eye_TUNEL.zip',
#   'file_size': 85843864,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC20_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.093,
#   'date_updated': 1685500662.093,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC19_ Mouse_Eye_TUNEL.zip',
#   'file_size': 64765905,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC19_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.097,
#   'date_updated': 1685500662.097,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC18_ Mouse_Eye_TUNEL.zip',
#   'file_size': 91390061,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC18_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.102,
#   'date_updated': 1685500662.102,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC17_ Mouse_Eye_TUNEL.zip',
#   'file_size': 68276985,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC17_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.106,
#   'date_updated': 1685500662.106,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC16_ Mouse_Eye_TUNEL.zip',
#   'file_size': 72172915,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC16_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.11,
#   'date_updated': 1685500662.11,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC15_ Mouse_Eye_TUNEL.zip',
#   'file_size': 54962341,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC15_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.114,
#   'date_updated': 1685500662.114,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F20_ Mouse_Eye_TUNEL.zip',
#   'file_size': 80533336,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F20_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.118,
#   'date_updated': 1685500662.118,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F19_ Mouse_Eye_TUNEL.zip',
#   'file_size': 71164874,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F19_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.122,
#   'date_updated': 1685500662.122,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F18_ Mouse_Eye_TUNEL.zip',
#   'file_size': 71895754,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F18_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.126,
#   'date_updated': 1685500662.126,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F17_ Mouse_Eye_TUNEL.zip',
#   'file_size': 74286131,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F17_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.131,
#   'date_updated': 1685500662.131,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F16_ Mouse_Eye_TUNEL.zip',
#   'file_size': 57901161,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F16_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.135,
#   'date_updated': 1685500662.135,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F15_ Mouse_Eye_TUNEL.zip',
#   'file_size': 73846626,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F15_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.139,
#   'date_updated': 1685500662.139,
#   'file_name': 'LSDS-5_immunostaining_microscopy_CC2_20_ Mouse_Eye_TUNEL.zip',
#   'file_size': 91713620,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_CC2_20_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.144,
#   'date_updated': 1685500662.144,
#   'file_name': 'LSDS-5_immunostaining_microscopy_CC2_18_ Mouse_Eye_TUNEL.zip',
#   'file_size': 112316363,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_CC2_18_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.148,
#   'date_updated': 1685500662.148,
#   'file_name': 'LSDS-5_immunostaining_microscopy_CC2_17_ Mouse_Eye_TUNEL.zip',
#   'file_size': 66868382,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_CC2_17_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.152,
#   'date_updated': 1685500662.152,
#   'file_name': 'LSDS-5_immunostaining_microscopy_CC2_16_ Mouse_Eye_TUNEL.zip',
#   'file_size': 56152721,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_CC2_16_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.156,
#   'date_updated': 1685500662.156,
#   'file_name': 'LSDS-5_immunostaining_microscopy_CC2_15_ Mouse_Eye_TUNEL.zip',
#   'file_size': 55198691,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_CC2_15_ '
#                 'Mouse_Eye_TUNEL.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.16,
#   'date_updated': 1685500662.16,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC19_ Mouse_Eye_PECAM.zip',
#   'file_size': 67791589,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC19_ '
#                 'Mouse_Eye_PECAM.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.164,
#   'date_updated': 1685500662.164,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC18_ Mouse_Eye_PECAM.zip',
#   'file_size': 121404964,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC18_ '
#                 'Mouse_Eye_PECAM.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.168,
#   'date_updated': 1685500662.168,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC17_ Mouse_Eye_PECAM.zip',
#   'file_size': 87933185,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC17_ '
#                 'Mouse_Eye_PECAM.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.173,
#   'date_updated': 1685500662.173,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC16_ Mouse_Eye_PECAM.zip',
#   'file_size': 72843699,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC16_ '
#                 'Mouse_Eye_PECAM.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.177,
#   'date_updated': 1685500662.177,
#   'file_name': 'LSDS-5_immunostaining_microscopy_GC15_ Mouse_Eye_PECAM.zip',
#   'file_size': 83954290,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_GC15_ '
#                 'Mouse_Eye_PECAM.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.181,
#   'date_updated': 1685500662.181,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F20_ Mouse_Eye_PECAM.zip',
#   'file_size': 74918531,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F20_ '
#                 'Mouse_Eye_PECAM.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.185,
#   'date_updated': 1685500662.185,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F19_ Mouse_Eye_PECAM.zip',
#   'file_size': 134694482,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F19_ '
#                 'Mouse_Eye_PECAM.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.189,
#   'date_updated': 1685500662.189,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F18_ Mouse_Eye_PECAM.zip',
#   'file_size': 133622137,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F18_ '
#                 'Mouse_Eye_PECAM.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.193,
#   'date_updated': 1685500662.193,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F17_ Mouse_Eye_PECAM.zip',
#   'file_size': 49578693,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F17_ '
#                 'Mouse_Eye_PECAM.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.197,
#   'date_updated': 1685500662.197,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F16_ Mouse_Eye_PECAM.zip',
#   'file_size': 57734573,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F16_ '
#                 'Mouse_Eye_PECAM.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685500662.202,
#   'date_updated': 1685500662.202,
#   'file_name': 'LSDS-5_immunostaining_microscopy_F15_ Mouse_Eye_PECAM.zip',
#   'file_size': 93786213,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-568/download?source=datamanager&file=LSDS-5_immunostaining_microscopy_F15_ '
#                 'Mouse_Eye_PECAM.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True}]
# Archive:  data/OSD-568/OSD-568_metadata_OSD-568-ISA.zip
#  extracting: data/OSD-568/metadata/a_OSD-568_molecular-cellular-imaging_microscopy_bz-x700 keyence corp (1).txt
#  extracting: data/OSD-568/metadata/a_OSD-568_molecular-cellular-imaging_microscopy_bz-x700 keyence corp (2).txt
#  extracting: data/OSD-568/metadata/a_OSD-568_molecular-cellular-imaging_microscopy_bz-x710-keyance.txt
#  extracting: data/OSD-568/metadata/i_Investigation.txt
#  extracting: data/OSD-568/metadata/s_OSD-568.txt
# Downloading and Extracting Files:  12%|█▏        | 6/51 [00:06<00:47,  1.06s/it]
# Archive:  data/OSD-568/LSDS-5_immunostaining_microscopy_GC19_Mouse_Eye_ZO.zip
#   inflating: data/OSD-568/images/GC19_ Mouse_Eye_ZO/GC19_RR9_Ret_20X_ZO/GC19_RR9_Ret_20X_ZO-1_CH1.tif
#   inflating: data/OSD-568/images/GC19_ Mouse_Eye_ZO/GC19_RR9_Ret_20X_ZO/GC19_RR9_Ret_20X_ZO-1_CH2.tif
#   inflating: data/OSD-568/images/GC19_ Mouse_Eye_ZO/GC19_RR9_Ret_20X_ZO/GC19_RR9_Ret_20X_ZO-1_CH3.tif
#   inflating: data/OSD-568/images/GC19_ Mouse_Eye_ZO/GC19_RR9_Ret_20X_ZO/GC19_RR9_Ret_20X_ZO-1_Overlay.tif
#   inflating: data/OSD-568/images/GC19_ Mouse_Eye_ZO/GC19_RR9_Ret_20X_ZO/GC19_RR9_Ret_20X_ZO-1_Overlay2.tif
#   inflating: data/OSD-568/images/GC19_ Mouse_Eye_ZO/GC19_RR9_Ret_20X_ZO_01/GC19_RR9_Ret_20X_ZO-2_CH1.tif
#   inflating: data/OSD-568/images/GC19_ Mouse_Eye_ZO/GC19_RR9_Ret_20X_ZO_01/GC19_RR9_Ret_20X_ZO-2_CH2.tif
#   inflating: data/OSD-568/images/GC19_ Mouse_Eye_ZO/GC19_RR9_Ret_20X_ZO_01/GC19_RR9_Ret_20X_ZO-2_CH3.tif
#   inflating: data/OSD-568/images/GC19_ Mouse_Eye_ZO/GC19_RR9_Ret_20X_ZO_01/GC19_RR9_Ret_20X_ZO-2_Overlay.tif
#   inflating: data/OSD-568/images/GC19_ Mouse_Eye_ZO/GC19_RR9_Ret_20X_ZO_01/GC19_RR9_Ret_20X_ZO-2_Overlay2.tif
#   inflating: data/OSD-568/images/GC19_ Mouse_Eye_ZO/GC19_RR9_Ret_20X_ZO_02/GC19_RR9_Ret_20X_ZO-3_CH1.tif
#   inflating: data/OSD-568/images/GC19_ Mouse_Eye_ZO/GC19_RR9_Ret_20X_ZO
tif
#   inflating: data/OSD-568/images/F15_ Mouse_Eye_PECAM/F15_RR9_Ret_20X_PECAM_14/F15_RR9_Ret_20X_PECAM-8_CH3.tif
#   inflating: data/OSD-568/images/F15_ Mouse_Eye_PECAM/F15_RR9_Ret_20X_PECAM_14/F15_RR9_Ret_20X_PECAM-8_Overlay.tif
# Downloading and Extracting Files: 100%|██████████| 51/51 [04:09<00:00,  4.89s/it]
#   inflating: data/OSD-568/images/F15_ Mouse_Eye_PECAM/F15_RR9_Ret_20X_PECAM_14/Thumbs.db

# %%
# 3. Examine and Download OSD-557 Study Files (Total file size: 2.5 GB [complete download])

file_list = list(df['studies.OSD-557.study_files'])

# pp(file_list)

# Filter entries within file_list with 'category' containing 'Study Metadata', or 'file_name' containing 'Normalized/Unnormalized'
metadata_files = [file for sublist in file_list for file in sublist if 'Study Metadata' in file['category']]
tomography_files = [file for sublist in file_list for file in sublist if 'Tomography' in file['category']]
microscopy_files = [file for sublist in file_list for file in sublist if 'Immunostaining Microscopy' in file['category']]
histology_files = [file for sublist in file_list for file in sublist if 'Histology' in file['category']]

pp(len(metadata_files))
pp(metadata_files)
pp(len(tomography_files))
pp(tomography_files)
pp(len(microscopy_files))
pp(microscopy_files)
pp(len(histology_files))
pp(histology_files)

# Download files into perspectively named folders

# 1. Create a directory for the OSD Study
study_folder_name = 'OSD-557'
os.makedirs(os.path.join('data', study_folder_name), exist_ok=True)

# 2. Download files
for file in metadata_files:
    file_url = 'https://osdr.nasa.gov' + file['remote_url']
    file_name = file['file_name']
    file_path = os.path.join('data', study_folder_name, file_name)

    # Download the file
    urlrequest.urlretrieve(file_url, file_path)

    # If file is a zip file, extract it
    if file_name.endswith('.zip'):
        os.system(f'unzip -o {file_path} -d {os.path.join("data", study_folder_name, 'metadata')}')
        # Remove the zip file
        os.remove(file_path)

for file in tqdm(tomography_files, desc="Downloading and Extracting Files"):
    # Encode the remote_url part to handle spaces and other special characters
    encoded_remote_url = quote(file['remote_url'], safe='/?:&=')
    file_url = 'https://osdr.nasa.gov' + encoded_remote_url
    file_name = file['file_name'].replace(' ', '')
    file_path = os.path.join('data', study_folder_name, file_name)
    
    # Download the file
    urlrequest.urlretrieve(file_url, file_path)
    
    # If file is a zip file, extract it
    if file_name.endswith('.zip'):
        os.system(f'unzip -o {file_path} -d {os.path.join('data', study_folder_name, 'tomography')}')
        # Remove the zip file
        os.remove(file_path)

for file in tqdm(microscopy_files, desc="Downloading and Extracting Files"):
    # Encode the remote_url part to handle spaces and other special characters
    encoded_remote_url = quote(file['remote_url'], safe='/?:&=')
    file_url = 'https://osdr.nasa.gov' + encoded_remote_url
    file_name = file['file_name'].replace(' ', '')
    file_path = os.path.join('data', study_folder_name, file_name)
    
    # Download the file
    urlrequest.urlretrieve(file_url, file_path)
    
    # If file is a zip file, extract it
    if file_name.endswith('.zip'):
        os.system(f'unzip -o {file_path} -d {os.path.join('data', study_folder_name, 'microscopy')}')
        # Remove the zip file
        os.remove(file_path)

for file in tqdm(histology_files, desc="Downloading and Extracting Files"):
    # Encode the remote_url part to handle spaces and other special characters
    encoded_remote_url = quote(file['remote_url'], safe='/?:&=')
    file_url = 'https://osdr.nasa.gov' + encoded_remote_url
    file_name = file['file_name'].replace(' ', '')
    file_path = os.path.join('data', study_folder_name, file_name)
    
    # Download the file
    urlrequest.urlretrieve(file_url, file_path)
    
    # If file is a zip file, extract it
    if file_name.endswith('.zip'):
        os.system(f'unzip -o {file_path} -d {os.path.join('data', study_folder_name, 'histology')}')
        # Remove the zip file
        os.remove(file_path)
# Out:
# 1
# [{'category': 'Study Metadata Files',
#   'date_created': 1685501268.482,
#   'date_updated': 1685501268.482,
#   'file_name': 'OSD-557_metadata_OSD-557-ISA.zip',
#   'file_size': 124209,
#   'organization': 'OSD',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=OSD-557_metadata_OSD-557-ISA.zip',
#   'restricted': False,
#   'subcategory': '',
#   'subdirectory': '',
#   'visible': True}]
# 2
# [{'category': 'Micro-Computed Tomography',
#   'date_created': 1685501268.486,
#   'date_updated': 1685501268.486,
#   'file_name': 'LSDS-1_microCT_MicroCT_Submitted_Results.xlsx',
#   'file_size': 232270,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_microCT_MicroCT_Submitted_Results.xlsx',
#   'restricted': False,
#   'subcategory': 'Tabular Result Files',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'Micro-Computed Tomography',
#   'date_created': 1685501268.491,
#   'date_updated': 1685501268.491,
#   'file_name': 'LSDS-1_microCT_MicroCT_Transformed_Reusable_Results.csv',
#   'file_size': 1403,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_microCT_MicroCT_Transformed_Reusable_Results.csv',
#   'restricted': False,
#   'subcategory': 'Tabular Result Files',
#   'subdirectory': 'alsda-processed',
#   'visible': True}]
# 27
# [{'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.495,
#   'date_updated': 1685501268.495,
#   'file_name': 'LSDS-1_immunostaining_microscopy_PNAtr_Transformed_Reusable_Results.csv',
#   'file_size': 788,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_PNAtr_Transformed_Reusable_Results.csv',
#   'restricted': False,
#   'subcategory': 'Tabular Result Files',
#   'subdirectory': 'ALSDA Transformed Reusable Files',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.499,
#   'date_updated': 1685501268.499,
#   'file_name': 'LSDS-1_immunostaining_microscopy_PNAtr_Submitted_Results.xlsx',
#   'file_size': 22562,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_PNAtr_Submitted_Results.xlsx',
#   'restricted': False,
#   'subcategory': 'Tabular Result Files',
#   'subdirectory': 'Original Submitted',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.503,
#   'date_updated': 1685501268.503,
#   'file_name': 'LSDS-1_immunostaining_microscopy_Viv20_Mouse_Eye.zip',
#   'file_size': 65301963,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_Viv20_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.507,
#   'date_updated': 1685501268.507,
#   'file_name': 'LSDS-1_immunostaining_microscopy_Viv19_Mouse_Eye.zip',
#   'file_size': 95131595,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_Viv19_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.511,
#   'date_updated': 1685501268.511,
#   'file_name': 'LSDS-1_immunostaining_microscopy_Viv18_Mouse_Eye.zip',
#   'file_size': 68350598,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_Viv18_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.515,
#   'date_updated': 1685501268.515,
#   'file_name': 'LSDS-1_immunostaining_microscopy_Viv17_Mouse_Eye.zip',
#   'file_size': 104970678,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_Viv17_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.52,
#   'date_updated': 1685501268.52,
#   'file_name': 'LSDS-1_immunostaining_microscopy_Viv16_Mouse_Eye.zip',
#   'file_size': 106591787,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_Viv16_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.524,
#   'date_updated': 1685501268.524,
#   'file_name': 'LSDS-1_immunostaining_microscopy_Viv15_Mouse_Eye.zip',
#   'file_size': 83302754,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_Viv15_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.528,
#   'date_updated': 1685501268.528,
#   'file_name': 'LSDS-1_immunostaining_microscopy_GC19_Mouse_Eye.zip',
#   'file_size': 58238004,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_GC19_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.532,
#   'date_updated': 1685501268.532,
#   'file_name': 'LSDS-1_immunostaining_microscopy_GC18_Mouse_Eye.zip',
#   'file_size': 91738812,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_GC18_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.536,
#   'date_updated': 1685501268.536,
#   'file_name': 'LSDS-1_immunostaining_microscopy_GC17_Mouse_Eye.zip',
#   'file_size': 83071290,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_GC17_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.54,
#   'date_updated': 1685501268.54,
#   'file_name': 'LSDS-1_immunostaining_microscopy_GC16_Mouse_Eye.zip',
#   'file_size': 67441058,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_GC16_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.544,
#   'date_updated': 1685501268.544,
#   'file_name': 'LSDS-1_immunostaining_microscopy_GC15_Mouse_Eye.zip',
#   'file_size': 67371862,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_GC15_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.549,
#   'date_updated': 1685501268.549,
#   'file_name': 'LSDS-1_immunostaining_microscopy_F20_Mouse_Eye.zip',
#   'file_size': 182070721,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_F20_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.553,
#   'date_updated': 1685501268.553,
#   'file_name': 'LSDS-1_immunostaining_microscopy_F19_Mouse_Eye.zip',
#   'file_size': 85376786,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_F19_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.557,
#   'date_updated': 1685501268.557,
#   'file_name': 'LSDS-1_immunostaining_microscopy_F18_Mouse_Eye.zip',
#   'file_size': 74659162,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_F18_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.561,
#   'date_updated': 1685501268.561,
#   'file_name': 'LSDS-1_immunostaining_microscopy_F17_Mouse_Eye.zip',
#   'file_size': 101902937,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_F17_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.566,
#   'date_updated': 1685501268.566,
#   'file_name': 'LSDS-1_immunostaining_microscopy_F16_Mouse_Eye.zip',
#   'file_size': 107913543,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_F16_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.57,
#   'date_updated': 1685501268.57,
#   'file_name': 'LSDS-1_immunostaining_microscopy_F15_Mouse_Eye.zip',
#   'file_size': 73235766,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_F15_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.574,
#   'date_updated': 1685501268.574,
#   'file_name': 'LSDS-1_immunostaining_microscopy_CC2_20_Mouse_Eye.zip',
#   'file_size': 148310615,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_CC2_20_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.578,
#   'date_updated': 1685501268.578,
#   'file_name': 'LSDS-1_immunostaining_microscopy_CC2_18_Mouse_Eye.zip',
#   'file_size': 105334941,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_CC2_18_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.583,
#   'date_updated': 1685501268.583,
#   'file_name': 'LSDS-1_immunostaining_microscopy_CC2_17_Mouse_Eye.zip',
#   'file_size': 79546181,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_CC2_17_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.587,
#   'date_updated': 1685501268.587,
#   'file_name': 'LSDS-1_immunostaining_microscopy_CC2_16_Mouse_Eye.zip',
#   'file_size': 64284705,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_CC2_16_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.591,
#   'date_updated': 1685501268.591,
#   'file_name': 'LSDS-1_immunostaining_microscopy_CC2_15_Mouse_Eye.zip',
#   'file_size': 108024688,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_CC2_15_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.667,
#   'date_updated': 1685501268.667,
#   'file_name': 'LSDS-1_immunostaining_microscopy_HNEtr_Submitted_Results.xlsx',
#   'file_size': 20848,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_HNEtr_Submitted_Results.xlsx',
#   'restricted': False,
#   'subcategory': 'Tabular Result Files',
#   'subdirectory': 'Original Submitted',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.671,
#   'date_updated': 1685501268.671,
#   'file_name': 'LSDS-1_immunostaining_microscopy_HNEtr_Transformed_Reusable_Results.csv',
#   'file_size': 1523,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_HNEtr_Transformed_Reusable_Results.csv',
#   'restricted': False,
#   'subcategory': 'Tabular Result Files',
#   'subdirectory': 'ALSDA Transformed Reusable Files',
#   'visible': True},
#  {'category': 'Immunostaining Microscopy',
#   'date_created': 1685501268.695,
#   'date_updated': 1685501268.695,
#   'file_name': 'LSDS-1_immunostaining_microscopy_GC20_Mouse_Eye.zip',
#   'file_size': 60241172,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_immunostaining_microscopy_GC20_Mouse_Eye.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Image',
#   'visible': True}]
# 23
# [{'category': 'Histology',
#   'date_created': 1685501268.595,
#   'date_updated': 1685501268.595,
#   'file_name': 'LSDS-1_Histology_V20_RR9_Ret_2X_HE_29.zip',
#   'file_size': 6495115,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_V20_RR9_Ret_2X_HE_29.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.599,
#   'date_updated': 1685501268.599,
#   'file_name': 'LSDS-1_Histology_V19_RR9_Ret_2X_HE_28.zip',
#   'file_size': 6514674,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_V19_RR9_Ret_2X_HE_28.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.603,
#   'date_updated': 1685501268.603,
#   'file_name': 'LSDS-1_Histology_V18_RR9_Ret_2X_HE_27.zip',
#   'file_size': 6536464,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_V18_RR9_Ret_2X_HE_27.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.608,
#   'date_updated': 1685501268.608,
#   'file_name': 'LSDS-1_Histology_V17_RR9_Ret_2X_HE_26.zip',
#   'file_size': 6463385,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_V17_RR9_Ret_2X_HE_26.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.612,
#   'date_updated': 1685501268.612,
#   'file_name': 'LSDS-1_Histology_V16_RR9_Ret_2X_HE_25.zip',
#   'file_size': 6522979,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_V16_RR9_Ret_2X_HE_25.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.616,
#   'date_updated': 1685501268.616,
#   'file_name': 'LSDS-1_Histology_V15_RR9_Ret_2X_HE_24.zip',
#   'file_size': 6550327,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_V15_RR9_Ret_2X_HE_24.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.62,
#   'date_updated': 1685501268.62,
#   'file_name': 'LSDS-1_Histology_GC19_RR9_Ret_2X_10X_HE.zip',
#   'file_size': 26248566,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_GC19_RR9_Ret_2X_10X_HE.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.625,
#   'date_updated': 1685501268.625,
#   'file_name': 'LSDS-1_Histology_GC18_RR9_Ret_2X_10X_HE.zip',
#   'file_size': 25851411,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_GC18_RR9_Ret_2X_10X_HE.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.629,
#   'date_updated': 1685501268.629,
#   'file_name': 'LSDS-1_Histology_GC17_RR9_Ret_2X_10X_HE.zip',
#   'file_size': 28140371,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_GC17_RR9_Ret_2X_10X_HE.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.633,
#   'date_updated': 1685501268.633,
#   'file_name': 'LSDS-1_Histology_GC16_RR9_Ret_2X_10X_HE.zip',
#   'file_size': 28725465,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_GC16_RR9_Ret_2X_10X_HE.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.637,
#   'date_updated': 1685501268.637,
#   'file_name': 'LSDS-1_Histology_GC15_RR9_Ret_2X_10X_HE.zip',
#   'file_size': 27463676,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_GC15_RR9_Ret_2X_10X_HE.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.641,
#   'date_updated': 1685501268.641,
#   'file_name': 'LSDS-1_Histology_F20_RR9_Ret_2X_10X_HE.zip',
#   'file_size': 38931262,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_F20_RR9_Ret_2X_10X_HE.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.646,
#   'date_updated': 1685501268.646,
#   'file_name': 'LSDS-1_Histology_F19_RR9_Ret_2X_10X_HE.zip',
#   'file_size': 26303786,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_F19_RR9_Ret_2X_10X_HE.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.65,
#   'date_updated': 1685501268.65,
#   'file_name': 'LSDS-1_Histology_F18_RR9_Ret_2X__10X_HE.zip',
#   'file_size': 25791452,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_F18_RR9_Ret_2X__10X_HE.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.654,
#   'date_updated': 1685501268.654,
#   'file_name': 'LSDS-1_Histology_F17_RR9_Ret_2X__10X_HE.zip',
#   'file_size': 28490741,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_F17_RR9_Ret_2X__10X_HE.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.658,
#   'date_updated': 1685501268.658,
#   'file_name': 'LSDS-1_Histology_F16_RR9_Ret_2X__10X_HE.zip',
#   'file_size': 28726229,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_F16_RR9_Ret_2X__10X_HE.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.663,
#   'date_updated': 1685501268.663,
#   'file_name': 'LSDS-1_Histology_F15_RR9_Ret_2X__10X_HE.zip',
#   'file_size': 33624687,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_F15_RR9_Ret_2X__10X_HE.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.675,
#   'date_updated': 1685501268.675,
#   'file_name': 'LSDS-1_Histology_CC2_20_RR9_Ret_2X_HE_34.zip',
#   'file_size': 6479613,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_CC2_20_RR9_Ret_2X_HE_34.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.679,
#   'date_updated': 1685501268.679,
#   'file_name': 'LSDS-1_Histology_CC2_18_RR9_Ret_2X_HE_33.zip',
#   'file_size': 6544667,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_CC2_18_RR9_Ret_2X_HE_33.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.683,
#   'date_updated': 1685501268.683,
#   'file_name': 'LSDS-1_Histology_CC2_17_RR9_Ret_2X_HE_32.zip',
#   'file_size': 6464768,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_CC2_17_RR9_Ret_2X_HE_32.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.687,
#   'date_updated': 1685501268.687,
#   'file_name': 'LSDS-1_Histology_CC2_16_RR9_Ret_2X_HE_31.zip',
#   'file_size': 6727719,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_CC2_16_RR9_Ret_2X_HE_31.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible': True},
#  {'category': 'Histology',
#   'date_created': 1685501268.691,
#   'date_updated': 1685501268.691,
#   'file_name': 'LSDS-1_Histology_CC2_15_RR9_Ret_2X_HE_30.zip',
#   'file_size': 6533139,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-557/download?source=datamanager&file=LSDS-1_Histology_CC2_15_RR9_Ret_2X_HE_30.zip',
#   'restricted': False,
#   'subcategory': 'Image Files',
#   'subdirectory': 'Raw Images',
#   'visible':
tif
#   inflating: data/OSD-557/microscopy/GC20_Mouse_Eye/GC20_RR9_Ret_20X_PNA-HNE_04/Thumbs.db
#    creating: data/OSD-557/microscopy/GC20_Mouse_Eye/GC20_RR9_Ret_20X_PNA-HNE_05/
#   inflating: data/OSD-557/microscopy/GC20_Mouse_Eye/GC20_RR9_Ret_20X_PNA-HNE_05/Chc20_RR9_Ret_20X_PNA-HNE-6_CH1.tif
#   inflating: data/OSD-557/microscopy/GC20_Mouse_Eye/GC20_RR9_Ret_20X_PNA-HNE_05/Chc20_RR9_Ret_20X_PNA-HNE-6_CH2.tif
#   inflating: data/OSD-557/microscopy/GC20_Mouse_Eye/GC20_RR9_Ret_20X_PNA-HNE_05/Chc20_RR9_Ret_20X_PNA-HNE-6_CH3.tif
#   inflating: data/OSD-557/microscopy/GC20_Mouse_Eye/GC20_RR9_Ret_20X_PNA-HNE_05/Chc20_RR9_Ret_20X_PNA-HNE-6_Overlay.tif
#    creating: data/OSD-557/microscopy/GC20_Mouse_Eye/GC20_RR9_Ret_20X_PNA-only_06/
#   inflating: data/OSD-557/microscopy/GC20_Mouse_Eye/GC20_RR9_Ret_20X_PNA-only_06/Chc20_RR9_Ret_20X_PNA-only-7_CH1.tif
#   inflating: data/OSD-557/microscopy/GC20_Mouse_Eye/GC20_RR9_Ret_20X_PNA-only_06/Chc20_RR9_Ret_20X_PNA-only-7_CH2.tif
#   inflating: data/OSD-557/microscopy/GC20_Mouse_Eye/GC20_RR9_Ret_20X_PNA-only_06/Chc20_RR9_Ret_20X_PNA-only-7_CH3.tif
#   inflating: data/OSD-557/microscopy/GC20_Mouse_Eye/GC20_RR9_Ret_20X_PNA-only_06/Chc20_RR9_Ret_20X_PNA-only-7_Overlay.tif
# Downloading and Extracting Files: 100%|██████████| 27/27 [02:23<00:00,  5.30s/it]
#   inflating: data/OSD-557/microscopy/GC20_Mouse_Eye/GC20_RR9_Ret_20X_PNA-only_06/Thumbs.db
# Downloading and Extracting Files:   4%|▍         | 1/23 [00:01<00:37,  1.71s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_V20_RR9_Ret_2X_HE_29.zip
#   inflating: data/OSD-557/histology/V20_RR9_Ret_2X_H&E_29.tif
# Downloading and Extracting Files:   9%|▊         | 2/23 [00:03<00:34,  1.66s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_V19_RR9_Ret_2X_HE_28.zip
#   inflating: data/OSD-557/histology/V19_RR9_Ret_2X_H&E_28.tif
# Downloading and Extracting Files:  13%|█▎        | 3/23 [00:05<00:35,  1.77s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_V18_RR9_Ret_2X_HE_27.zip
#   inflating: data/OSD-557/histology/V18_RR9_Ret_2X_H&E_27.tif
# Downloading and Extracting Files:  17%|█▋        | 4/23 [00:06<00:32,  1.69s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_V17_RR9_Ret_2X_HE_26.zip
#   inflating: data/OSD-557/histology/V17_RR9_Ret_2X_H&E_26.tif
# Downloading and Extracting Files:  22%|██▏       | 5/23 [00:08<00:30,  1.67s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_V16_RR9_Ret_2X_HE_25.zip
#   inflating: data/OSD-557/histology/V16_RR9_Ret_2X_H&E_25.tif
# Downloading and Extracting Files:  26%|██▌       | 6/23 [00:09<00:27,  1.63s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_V15_RR9_Ret_2X_HE_24.zip
#   inflating: data/OSD-557/histology/V15_RR9_Ret_2X_H&E_24.tif
# Downloading and Extracting Files:  30%|███       | 7/23 [00:12<00:30,  1.91s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_GC19_RR9_Ret_2X_10X_HE.zip
#   inflating: data/OSD-557/histology/GC19_RR9_Ret_10X_H&E.tif
#   inflating: data/OSD-557/histology/GC19_RR9_Ret_10X_H&E_01.tif
#   inflating: data/OSD-557/histology/GC19_RR9_Ret_10X_H&E_02.tif
#   inflating: data/OSD-557/histology/GC19_RR9_Ret_2X_H&E_20.tif
# Downloading and Extracting Files:  35%|███▍      | 8/23 [00:15<00:31,  2.11s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_GC18_RR9_Ret_2X_10X_HE.zip
#   inflating: data/OSD-557/histology/GC18_RR9_Ret_10X_H&E.tif
#   inflating: data/OSD-557/histology/GC18_RR9_Ret_10X_H&E_01.tif
#   inflating: data/OSD-557/histology/GC18_RR9_Ret_10X_H&E_02.tif
#   inflating: data/OSD-557/histology/GC18_RR9_Ret_2X_H&E_19.tif
# Downloading and Extracting Files:  39%|███▉      | 9/23 [00:18<00:33,  2.40s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_GC17_RR9_Ret_2X_10X_HE.zip
#   inflating: data/OSD-557/histology/GC17_RR9_Ret_10X_H&E.tif
#   inflating: data/OSD-557/histology/GC17_RR9_Ret_10X_H&E_01.tif
#   inflating: data/OSD-557/histology/GC17_RR9_Ret_10X_H&E_02.tif
#   inflating: data/OSD-557/histology/GC17_RR9_Ret_2X_H&E_17.tif
# Archive:  data/OSD-557/LSDS-1_Histology_GC16_RR9_Ret_2X_10X_HE.zip
#   inflating: data/OSD-557/histology/GC16_RR9_Ret_10X_H&E.tif
#   inflating: data/OSD-557/histology/GC16_RR9_Ret_10X_H&E_01.tif
#   inflating: data/OSD-557/histology/GC16_RR9_Ret_10X_H&E_02.tif
#   inflating: data/OSD-557/histology/GC16_RR9_Ret_2X_H&E_14.tif
# Downloading and Extracting Files:  48%|████▊     | 11/23 [00:23<00:30,  2.56s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_GC15_RR9_Ret_2X_10X_HE.zip
#   inflating: data/OSD-557/histology/GC15_RR9_Ret_10X_H&E.tif
#   inflating: data/OSD-557/histology/GC15_RR9_Ret_10X_H&E_01.tif
#   inflating: data/OSD-557/histology/GC15_RR9_Ret_10X_H&E_02.tif
#   inflating: data/OSD-557/histology/GC15_RR9_Ret_2X_H&E_12.tif
# Archive:  data/OSD-557/LSDS-1_Histology_F20_RR9_Ret_2X_10X_HE.zip
#   inflating: data/OSD-557/histology/F20_RR9_Ret_10X_H&E.tif
#   inflating: data/OSD-557/histology/F20_RR9_Ret_10X_H&E_01.tif
#   inflating: data/OSD-557/histology/F20_RR9_Ret_10X_H&E_02.tif
#   inflating: data/OSD-557/histology/F20_RR9_Ret_10X_H&E_03.tif
#   inflating: data/OSD-557/histology/F20_RR9_Ret_2X_H&E_10.tif
#   inflating: data/OSD-557/histology/F20_RR9_Ret_2X_H&E_11.tif
# Downloading and Extracting Files:  52%|█████▏    | 12/23 [00:26<00:30,  2.74s/it]
# Downloading and Extracting Files:  57%|█████▋    | 13/23 [00:29<00:26,  2.65s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_F19_RR9_Ret_2X_10X_HE.zip
#   inflating: data/OSD-557/histology/F19_RR9_Ret_10X_H&E.tif
#   inflating: data/OSD-557/histology/F19_RR9_Ret_10X_H&E_01.tif
#   inflating: data/OSD-557/histology/F19_RR9_Ret_10X_H&E_02.tif
#   inflating: data/OSD-557/histology/F19_RR9_Ret_2X_H&E_09.tif
# Downloading and Extracting Files:  61%|██████    | 14/23 [00:31<00:23,  2.65s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_F18_RR9_Ret_2X__10X_HE.zip
#   inflating: data/OSD-557/histology/F18_RR9_Ret_10X_H&E.tif
#   inflating: data/OSD-557/histology/F18_RR9_Ret_10X_H&E_01.tif
#   inflating: data/OSD-557/histology/F18_RR9_Ret_10X_H&E_02.tif
#   inflating: data/OSD-557/histology/F18_RR9_Ret_2X_H&E_06.tif
# Downloading and Extracting Files:  65%|██████▌   | 15/23 [00:34<00:20,  2.57s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_F17_RR9_Ret_2X__10X_HE.zip
#   inflating: data/OSD-557/histology/F17_RR9_Ret_10X_H&E.tif
#   inflating: data/OSD-557/histology/F17_RR9_Ret_10X_H&E_01.tif
#   inflating: data/OSD-557/histology/F17_RR9_Ret_10X_H&E_02.tif
#   inflating: data/OSD-557/histology/F17_RR9_Ret_2X_H&E_04.tif
# Downloading and Extracting Files:  70%|██████▉   | 16/23 [00:36<00:17,  2.56s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_F16_RR9_Ret_2X__10X_HE.zip
#   inflating: data/OSD-557/histology/F16_RR9_Ret_10X_H&E.tif
#   inflating: data/OSD-557/histology/F16_RR9_Ret_10X_H&E_01.tif
#   inflating: data/OSD-557/histology/F16_RR9_Ret_10X_H&E_02.tif
#   inflating: data/OSD-557/histology/F16_RR9_Ret_2X_H&E_02.tif
# Archive:  data/OSD-557/LSDS-1_Histology_F15_RR9_Ret_2X__10X_HE.zip
#   inflating: data/OSD-557/histology/F15_RR9_Ret_10X_H&E.tif
#   inflating: data/OSD-557/histology/F15_RR9_Ret_10X_H&E_01.tif
#   inflating: data/OSD-557/histology/F15_RR9_Ret_10X_H&E_02.tif
#   inflating: data/OSD-557/histology/F15_RR9_Ret_10X_H&E_03.tif
#   inflating: data/OSD-557/histology/F15_RR9_Ret_2X_H&E.tif
# Downloading and Extracting Files:  74%|███████▍  | 17/23 [00:39<00:15,  2.65s/it]
# Downloading and Extracting Files:  78%|███████▊  | 18/23 [00:41<00:11,  2.34s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_CC2_20_RR9_Ret_2X_HE_34.zip
#   inflating: data/OSD-557/histology/VG20_RR9_Ret_2X_H&E_34.tif
# Downloading and Extracting Files:  83%|████████▎ | 19/23 [00:42<00:08,  2.13s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_CC2_18_RR9_Ret_2X_HE_33.zip
#   inflating: data/OSD-557/histology/VG18_RR9_Ret_2X_H&E_33.tif
# Downloading and Extracting Files:  87%|████████▋ | 20/23 [00:44<00:06,  2.01s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_CC2_17_RR9_Ret_2X_HE_32.zip
#   inflating: data/OSD-557/histology/VG17_RR9_Ret_2X_H&E_32.tif
# Downloading and Extracting Files:  91%|█████████▏| 21/23 [00:46<00:03,  1.88s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_CC2_16_RR9_Ret_2X_HE_31.zip
#   inflating: data/OSD-557/histology/VG16_RR9_Ret_2X_H&E_31.tif
# Downloading and Extracting Files:  96%|█████████▌| 22/23 [00:47<00:01,  1.85s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_CC2_15_RR9_Ret_2X_HE_30.zip
#   inflating: data/OSD-557/histology/VG15_RR9_Ret_2X_H&E_30.tif
# Downloading and Extracting Files: 100%|██████████| 23/23 [00:50<00:00,  2.19s/it]
# Archive:  data/OSD-557/LSDS-1_Histology_GC20_RR9_Ret_2X_10X_HE.zip
#   inflating: data/OSD-557/histology/GC20_RR9_Ret_2X_10X_H&E/ChC20_RR9_Ret_2X_H&E_22.tif
#   inflating: data/OSD-557/histology/GC20_RR9_Ret_2X_10X_H&E/GC20_RR9_Ret_10X_H&E.tif
#   inflating: data/OSD-557/histology/GC20_RR9_Ret_2X_10X_H&E/GC20_RR9_Ret_10X_H&E_01.tif
#   inflating: data/OSD-557/histology/GC20_RR9_Ret_2X_10X_H&E/GC20_RR9_Ret_10X_H&E_02.tif

# %%
# 4. Examine and Download OSD-583 Study Files (Total file size: 200 KB [complete download])

file_list = list(df['studies.OSD-583.study_files'])

#pp(file_list)

# Filter entries within file_list with 'category' containing 'Study Metadata', or 'file_name' containing 'Normalized/Unnormalized'
metadata_files = [file for sublist in file_list for file in sublist if 'Study Metadata' in file['category']]
processed_files = [file for sublist in file_list for file in sublist if 'Tonometry' in file['category']]

pp(len(metadata_files))
pp(metadata_files)
pp(len(processed_files))
pp(processed_files)

# Download files into perspectively named folders

# 1. Create a directory for the OSD Study
study_folder_name = 'OSD-583'
os.makedirs(os.path.join('data', study_folder_name), exist_ok=True)

# 2. Download files
for file in metadata_files:
    file_url = 'https://osdr.nasa.gov' + file['remote_url']
    file_name = file['file_name']
    file_path = os.path.join('data', study_folder_name, file_name)
    urlrequest.urlretrieve(file_url, file_path)
    # If file is a zip file, extract it
    if file_name.endswith('.zip'):
        os.system(f'unzip -o {file_path} -d {os.path.join("data", study_folder_name, 'metadata')}')
        # Remove the zip file
        os.remove(file_path)

for file in processed_files:
    file_url = 'https://osdr.nasa.gov' + file['remote_url']
    file_name = file['file_name']
    file_path = os.path.join('data', study_folder_name, file_name)
    urlrequest.urlretrieve(file_url, file_path)
# Out:
# 1
# [{'category': 'Study Metadata Files',
#   'date_created': 1674874083.645,
#   'date_updated': 1674874083.645,
#   'file_name': 'OSD-583_metadata_OSD-583-ISA.zip',
#   'file_size': 96659,
#   'organization': 'OSD',
#   'remote_url': '/geode-py/ws/studies/OSD-583/download?source=datamanager&file=OSD-583_metadata_OSD-583-ISA.zip',
#   'restricted': False,
#   'subcategory': '',
#   'subdirectory': '',
#   'visible': True}]
# 2
# [{'category': 'Tonometry',
#   'date_created': 1674874083.649,
#   'date_updated': 1674874083.649,
#   'file_name': 'LSDS-16_tonometry_mao_IOPsubmitted_results.xlsx',
#   'file_size': 79887,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-583/download?source=datamanager&file=LSDS-16_tonometry_mao_IOPsubmitted_results.xlsx',
#   'restricted': False,
#   'subcategory': 'Tabular Results Files',
#   'subdirectory': 'Submitted Results Files',
#   'visible': True},
#  {'category': 'Tonometry',
#   'date_created': 1674874083.653,
#   'date_updated': 1674874083.653,
#   'file_name': 'LSDS-16_tonometry_maoTRANSFORMED.csv',
#   'file_size': 8272,
#   'organization': 'alsda',
#   'remote_url': '/geode-py/ws/studies/OSD-583/download?source=datamanager&file=LSDS-16_tonometry_maoTRANSFORMED.csv',
#   'restricted': False,
#   'subcategory': 'Tabular Results Files',
#   'subdirectory': 'Transformed Reusable Files',
#   'visible': True}]
# Archive:  data/OSD-583/OSD-583_metadata_OSD-583-ISA.zip
#  extracting: data/OSD-583/metadata/i_Investigation.txt
#  extracting: data/OSD-583/metadata/s_OSD-583.txt
#  extracting: data/OSD-583/metadata/a_OSD-583_intraocular-pressure_tonometry_tonolab-icare.txt

# %%
# 5. Examine and Download OSD-397 Study Files (Total file size: 14 MB [incomplete download, only results])

file_list = list(df['studies.OSD-397.study_files'])

#pp(file_list)

# Filter entries within file_list with 'category' containing 'Study Metadata', or 'file_name' containing 'Normalized/Unnormalized'
metadata_files = [file for sublist in file_list for file in sublist if 'Study Metadata' in file['category']]
processed_files = [file for sublist in file_list for file in sublist if 'Normalized' in file['file_name'] or 'Unnormalized' in file['file_name']]

pp(len(metadata_files))
pp(metadata_files)
pp(len(processed_files))
pp(processed_files)

# Download files into perspectively named folders

# 1. Create a directory for the OSD Study
study_folder_name = 'OSD-397'
os.makedirs(os.path.join('data', study_folder_name), exist_ok=True)

# 2. Download files
for file in metadata_files:
    file_url = 'https://osdr.nasa.gov' + file['remote_url']
    file_name = file['file_name']
    file_path = os.path.join('data', study_folder_name, file_name)
    urlrequest.urlretrieve(file_url, file_path)
    # If file is a zip file, extract it
    if file_name.endswith('.zip'):
        os.system(f'unzip -o {file_path} -d {os.path.join("data", study_folder_name, 'metadata')}')
        # Remove the zip file
        os.remove(file_path)

for file in processed_files:
    file_url = 'https://osdr.nasa.gov' + file['remote_url']
    file_name = file['file_name']
    file_path = os.path.join('data', study_folder_name, file_name)
    urlrequest.urlretrieve(file_url, file_path)
# Out:
# 1
# [{'category': 'Study Metadata Files',
#   'date_created': 1709959943.366,
#   'date_updated': 1709959943.366,
#   'file_name': 'OSD-397_metadata_OSD-397-ISA.zip',
#   'file_size': 67118,
#   'organization': 'OSD',
#   'remote_url': '/geode-py/ws/studies/OSD-397/download?source=datamanager&file=OSD-397_metadata_OSD-397-ISA.zip',
#   'restricted': False,
#   'subcategory': '',
#   'subdirectory': '',
#   'visible': True}]
# 3
# [{'category': 'GeneLab Processed RNA-Seq Files',
#   'date_created': 1709959953.325,
#   'date_updated': 1709959953.325,
#   'file_name': 'GLDS-397_rna_seq_Normalized_Counts.csv',
#   'file_size': 6852201,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-397/download?source=datamanager&file=GLDS-397_rna_seq_Normalized_Counts.csv',
#   'restricted': False,
#   'subcategory': 'Normalized Counts Data',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed RNA-Seq Files',
#   'date_created': 1709959953.624,
#   'date_updated': 1709959953.624,
#   'file_name': 'GLDS-397_rna_seq_STAR_Unnormalized_Counts.csv',
#   'file_size': 3590203,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-397/download?source=datamanager&file=GLDS-397_rna_seq_STAR_Unnormalized_Counts.csv',
#   'restricted': False,
#   'subcategory': 'Raw Counts Tables',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed RNA-Seq Files',
#   'date_created': 1709959953.674,
#   'date_updated': 1709959953.674,
#   'file_name': 'GLDS-397_rna_seq_RSEM_Unnormalized_Counts.csv',
#   'file_size': 3709382,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-397/download?source=datamanager&file=GLDS-397_rna_seq_RSEM_Unnormalized_Counts.csv',
#   'restricted': False,
#   'subcategory': 'Raw Counts Tables',
#   'subdirectory': '',
#   'visible': True}]
# Archive:  data/OSD-397/OSD-397_metadata_OSD-397-ISA.zip
#  extracting: data/OSD-397/metadata/s_OSD-397.txt
#  extracting: data/OSD-397/metadata/a_OSD-397_transcription-profiling_rna-sequencing-(rna-seq)_illumina.txt
#  extracting: data/OSD-397/metadata/a_OSD-397_dna-methylation-profiling_reduced-representation-bisulfite-sequencing_illumina.txt
#  extracting: data/OSD-397/metadata/i_Investigation.txt

# %%
# 6. Examine and Download OSD-203 Study Files (Total file size: 57 MB [incomplete download, only results])

file_list = list(df['studies.OSD-203.study_files'])

#pp(file_list)

# Filter entries within file_list with 'category' containing 'Study Metadata', or 'file_name' containing 'Normalized/Unnormalized'
metadata_files = [file for sublist in file_list for file in sublist if 'Study Metadata' in file['category']]
processed_files = [file for sublist in file_list for file in sublist if 'Normalized' in file['file_name'] or 'Unnormalized' in file['file_name']]

pp(len(metadata_files))
pp(metadata_files)
pp(len(processed_files))
pp(processed_files)

# Download files into perspectively named folders

# 1. Create a directory for the OSD Study
study_folder_name = 'OSD-203'
os.makedirs(os.path.join('data', study_folder_name), exist_ok=True)

# 2. Download files
for file in metadata_files:
    file_url = 'https://osdr.nasa.gov' + file['remote_url']
    file_name = file['file_name']
    file_path = os.path.join('data', study_folder_name, file_name)
    urlrequest.urlretrieve(file_url, file_path)
    # If file is a zip file, extract it
    if file_name.endswith('.zip'):
        os.system(f'unzip -o {file_path} -d {os.path.join("data", study_folder_name, 'metadata')}')
        # Remove the zip file
        os.remove(file_path)

for file in processed_files:
    file_url = 'https://osdr.nasa.gov' + file['remote_url']
    file_name = file['file_name']
    file_path = os.path.join('data', study_folder_name, file_name)
    urlrequest.urlretrieve(file_url, file_path)
# Out:
# 1
# [{'category': 'Study Metadata Files',
#   'date_created': 1632962673.191,
#   'date_updated': 1632962673.191,
#   'file_name': 'GLDS-203_metadata_GLDS-203-ISA.zip',
#   'file_size': 17506,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-203/download?source=datamanager&file=GLDS-203_metadata_GLDS-203-ISA.zip',
#   'restricted': False,
#   'subcategory': '',
#   'subdirectory': '',
#   'visible': True}]
# 3
# [{'category': 'GeneLab Processed RNA-Seq Files',
#   'date_created': 1632962676.735,
#   'date_updated': 1632962676.735,
#   'file_name': 'GLDS-203_rna_seq_Unnormalized_Counts.csv',
#   'file_size': 10141486,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-203/download?source=datamanager&file=GLDS-203_rna_seq_Unnormalized_Counts.csv',
#   'restricted': False,
#   'subcategory': 'Raw counts data',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed RNA-Seq Files',
#   'date_created': 1632962676.764,
#   'date_updated': 1632962676.764,
#   'file_name': 'GLDS-203_rna_seq_ERCC_Normalized_Counts.csv',
#   'file_size': 24503711,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-203/download?source=datamanager&file=GLDS-203_rna_seq_ERCC_Normalized_Counts.csv',
#   'restricted': False,
#   'subcategory': 'Normalized counts data',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed RNA-Seq Files',
#   'date_created': 1632962676.793,
#   'date_updated': 1632962676.793,
#   'file_name': 'GLDS-203_rna_seq_Normalized_Counts.csv',
#   'file_size': 24484589,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-203/download?source=datamanager&file=GLDS-203_rna_seq_Normalized_Counts.csv',
#   'restricted': False,
#   'subcategory': 'Normalized counts data',
#   'subdirectory': '',
#   'visible': True}]
# Archive:  data/OSD-203/GLDS-203_metadata_GLDS-203-ISA.zip
#   inflating: data/OSD-203/metadata/s_LDR-HLU_Retina.txt
#   inflating: data/OSD-203/metadata/i_Investigation.txt
#   inflating: data/OSD-203/metadata/a_ldr-hlu_retina_transcription_profiling_RNA_Sequencing_(RNA-Seq).txt
#   inflating: data/OSD-203/metadata/a_ldr-hlu_retina_DNA_methylation_profiling_Bisulfite_sequencing.txt

# %%
# 7. Examine and Download OSD-194 Study Files (Total file size: 15 MB [incomplete download, only results])

file_list = list(df['studies.OSD-194.study_files'])

#pp(file_list)

# Filter entries within file_list with 'category' containing 'Study Metadata', or 'file_name' containing 'Normalized/Unnormalized'
metadata_files = [file for sublist in file_list for file in sublist if 'Study Metadata' in file['category']]
processed_files = [file for sublist in file_list for file in sublist if 'Normalized' in file['file_name'] or 'Unnormalized' in file['file_name']]

pp(len(metadata_files))
pp(metadata_files)
pp(len(processed_files))
pp(processed_files)

# Download files into perspectively named folders

# 1. Create a directory for the OSD Study
study_folder_name = 'OSD-194'
os.makedirs(os.path.join('data', study_folder_name), exist_ok=True)

# 2. Download files
for file in metadata_files:
    file_url = 'https://osdr.nasa.gov' + file['remote_url']
    file_name = file['file_name']
    file_path = os.path.join('data', study_folder_name, file_name)
    urlrequest.urlretrieve(file_url, file_path)
    # If file is a zip file, extract it
    if file_name.endswith('.zip'):
        os.system(f'unzip -o {file_path} -d {os.path.join("data", study_folder_name, 'metadata')}')
        # Remove the zip file
        os.remove(file_path)

for file in processed_files:
    file_url = 'https://osdr.nasa.gov' + file['remote_url']
    file_name = file['file_name']
    file_path = os.path.join('data', study_folder_name, file_name)
    urlrequest.urlretrieve(file_url, file_path)
# Out:
# 1
# [{'category': 'Study Metadata Files',
#   'date_created': 1680153390.2,
#   'date_updated': 1680153390.2,
#   'file_name': 'OSD-194_metadata_OSD-194-ISA.zip',
#   'file_size': 11260,
#   'organization': 'OSD',
#   'remote_url': '/geode-py/ws/studies/OSD-194/download?source=datamanager&file=OSD-194_metadata_OSD-194-ISA.zip',
#   'restricted': False,
#   'subcategory': '',
#   'subdirectory': '',
#   'visible': True}]
# 3
# [{'category': 'GeneLab Processed RNA-Seq Files',
#   'date_created': 1680153389.458,
#   'date_updated': 1680153389.458,
#   'file_name': 'GLDS-194_rna_seq_ERCC_Normalized_Counts.csv',
#   'file_size': 6065608,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-194/download?source=datamanager&file=GLDS-194_rna_seq_ERCC_Normalized_Counts.csv',
#   'restricted': False,
#   'subcategory': 'Normalized Counts Data',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed RNA-Seq Files',
#   'date_created': 1680153389.465,
#   'date_updated': 1680153389.465,
#   'file_name': 'GLDS-194_rna_seq_Normalized_Counts.csv',
#   'file_size': 6057432,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-194/download?source=datamanager&file=GLDS-194_rna_seq_Normalized_Counts.csv',
#   'restricted': False,
#   'subcategory': 'Normalized Counts Data',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed RNA-Seq Files',
#   'date_created': 1596262983.373,
#   'date_updated': 1596262983.373,
#   'file_name': 'GLDS-194_rna_seq_Unnormalized_Counts.csv',
#   'file_size': 3335491,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-194/download?source=datamanager&file=GLDS-194_rna_seq_Unnormalized_Counts.csv',
#   'restricted': False,
#   'subcategory': 'Raw counts data',
#   'subdirectory': '',
#   'visible': True}]
# Archive:  data/OSD-194/OSD-194_metadata_OSD-194-ISA.zip
#   inflating: data/OSD-194/metadata/s_OSD-194.txt
#   inflating: data/OSD-194/metadata/a_OSD-194_transcription-profiling_rna-sequencing-(rna-seq)_illumina.txt
#   inflating: data/OSD-194/metadata/i_Investigation.txt

# %%
# 8. Examine and Download OSD-87 Study Files (Total file size: 90 MB [complete download])

file_list = list(df['studies.OSD-87.study_files'])

#pp(len(file_list[0]))
#pp(file_list)

# Filter entries within file_list with 'category' containing 'Study Metadata', or 'file_name' containing 'Normalized/Unnormalized'
metadata_files = [file for sublist in file_list for file in sublist if 'Study Metadata' in file['category']]
processed_files = [file for sublist in file_list for file in sublist if 'Microarray Data Files' in file['category']]

pp(len(metadata_files))
pp(metadata_files)
pp(len(processed_files))
pp(processed_files)

# Download files into perspectively named folders

# 1. Create a directory for the OSD Study
study_folder_name = 'OSD-87'
os.makedirs(os.path.join('data', study_folder_name), exist_ok=True)

# 2. Download files
for file in metadata_files:
    file_url = 'https://osdr.nasa.gov' + file['remote_url']
    file_name = file['file_name']
    file_path = os.path.join('data', study_folder_name, file_name)
    urlrequest.urlretrieve(file_url, file_path)
    # If file is a zip file, extract it
    if file_name.endswith('.zip'):
        os.system(f'unzip -o {file_path} -d {os.path.join("data", study_folder_name, 'metadata')}')
        # Remove the zip file
        os.remove(file_path)

for file in tqdm(processed_files, desc="Downloading and Extracting Files"):
    file_url = 'https://osdr.nasa.gov' + file['remote_url']
    file_name = file['file_name']
    file_path = os.path.join('data', study_folder_name, file_name)
    urlrequest.urlretrieve(file_url, file_path)
# Out:
# 1
# [{'category': 'Study Metadata Files',
#   'date_created': 1601509296.578,
#   'date_updated': 1601509296.578,
#   'file_name': 'GLDS-87_metadata_Zanello_STS135-ISA.zip',
#   'file_size': 6504,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_metadata_Zanello_STS135-ISA.zip',
#   'restricted': False,
#   'subcategory': '',
#   'subdirectory': '',
#   'visible': True}]
# 28
# [{'category': 'Microarray Data Files',
#   'date_created': 1506033834.109,
#   'date_updated': '',
#   'file_name': 'GLDS-87_microarray_14R_(Mouse430_2).CEL.gz',
#   'file_size': 6374949,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_microarray_14R_(Mouse430_2).CEL.gz',
#   'restricted': False,
#   'subcategory': '',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'Microarray Data Files',
#   'date_created': 1506033834.109,
#   'date_updated': '',
#   'file_name': 'GLDS-87_microarray_16R_(Mouse430_2).CEL.gz',
#   'file_size': 6274393,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_microarray_16R_(Mouse430_2).CEL.gz',
#   'restricted': False,
#   'subcategory': '',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'Microarray Data Files',
#   'date_created': 1506033834.109,
#   'date_updated': '',
#   'file_name': 'GLDS-87_microarray_20R_(Mouse430_2).CEL.gz',
#   'file_size': 6384622,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_microarray_20R_(Mouse430_2).CEL.gz',
#   'restricted': False,
#   'subcategory': '',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'Microarray Data Files',
#   'date_created': 1506033834.109,
#   'date_updated': '',
#   'file_name': 'GLDS-87_microarray_52R_(Mouse430_2).CEL.gz',
#   'file_size': 6297226,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_microarray_52R_(Mouse430_2).CEL.gz',
#   'restricted': False,
#   'subcategory': '',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'Microarray Data Files',
#   'date_created': 1506033834.109,
#   'date_updated': '',
#   'file_name': 'GLDS-87_microarray_54R_(Mouse430_2).CEL.gz',
#   'file_size': 6017124,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_microarray_54R_(Mouse430_2).CEL.gz',
#   'restricted': False,
#   'subcategory': '',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'Microarray Data Files',
#   'date_created': 1506033834.109,
#   'date_updated': '',
#   'file_name': 'GLDS-87_microarray_58R_(Mouse430_2).CEL.gz',
#   'file_size': 6329707,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_microarray_58R_(Mouse430_2).CEL.gz',
#   'restricted': False,
#   'subcategory': '',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096747.138,
#   'date_updated': 1582096747.138,
#   'file_name': 'GLDS-87_array_arrayInfo.txt',
#   'file_size': 22,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_arrayInfo.txt',
#   'restricted': False,
#   'subcategory': 'Raw Data',
#   'subdirectory': 'Supplemental Materials',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096914.007,
#   'date_updated': 1582096914.007,
#   'file_name': 'GLDS-87_array_normPlotMA.png',
#   'file_size': 53306,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_normPlotMA.png',
#   'restricted': False,
#   'subcategory': 'Normalized Data',
#   'subdirectory': 'Plots and Images',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096913.945,
#   'date_updated': 1582096913.945,
#   'file_name': 'GLDS-87_array_normDensityDistributions.png',
#   'file_size': 31684,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_normDensityDistributions.png',
#   'restricted': False,
#   'subcategory': 'Normalized Data',
#   'subdirectory': 'Plots and Images',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096731.523,
#   'date_updated': 1582096731.523,
#   'file_name': 'GLDS-87_array_rawBoxplot.png',
#   'file_size': 16808,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_rawBoxplot.png',
#   'restricted': False,
#   'subcategory': 'Raw Data',
#   'subdirectory': 'Plots and Images',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096731.598,
#   'date_updated': 1582096731.598,
#   'file_name': 'GLDS-87_array_rawPCA.png',
#   'file_size': 27096,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_rawPCA.png',
#   'restricted': False,
#   'subcategory': 'Raw Data',
#   'subdirectory': 'Plots and Images',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096842.387,
#   'date_updated': 1582096842.387,
#   'file_name': 'GLDS-87_array_contrasts.csv',
#   'file_size': 113,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_contrasts.csv',
#   'restricted': False,
#   'subcategory': 'Differential Expression Analyses',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096731.579,
#   'date_updated': 1582096731.579,
#   'file_name': 'GLDS-87_array_images.png',
#   'file_size': 70088,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_images.png',
#   'restricted': False,
#   'subcategory': 'Raw Data',
#   'subdirectory': 'Plots and Images',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096795.516,
#   'date_updated': 1582096795.516,
#   'file_name': 'GLDS-87_array_normalized-annotated.txt.gz',
#   'file_size': 958911,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_normalized-annotated.txt.gz',
#   'restricted': False,
#   'subcategory': 'Normalized Data',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096753.867,
#   'date_updated': 1582096753.867,
#   'file_name': 'GLDS-87_array_md5sum.txt',
#   'file_size': 471,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_md5sum.txt',
#   'restricted': False,
#   'subcategory': 'Raw Data',
#   'subdirectory': 'QC Reports',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096935.016,
#   'date_updated': 1582096935.016,
#   'file_name': 'GLDS-87_array_annotReport.txt',
#   'file_size': 207,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_annotReport.txt',
#   'restricted': False,
#   'subcategory': 'Normalized Data',
#   'subdirectory': 'QC Reports',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096731.521,
#   'date_updated': 1582096731.521,
#   'file_name': 'GLDS-87_array_rawDensityDistributions.png',
#   'file_size': 44207,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_rawDensityDistributions.png',
#   'restricted': False,
#   'subcategory': 'Raw Data',
#   'subdirectory': 'Plots and Images',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096795.849,
#   'date_updated': 1582096795.849,
#   'file_name': 'GLDS-87_array_normalized-annotated.rda',
#   'file_size': 881794,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_normalized-annotated.rda',
#   'restricted': False,
#   'subcategory': 'Normalized Data',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096795.474,
#   'date_updated': 1582096795.474,
#   'file_name': 'GLDS-87_array_normalized.txt.gz',
#   'file_size': 2315472,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_normalized.txt.gz',
#   'restricted': False,
#   'subcategory': 'Normalized Data',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096914.065,
#   'date_updated': 1582096914.065,
#   'file_name': 'GLDS-87_array_normBoxplot.png',
#   'file_size': 16284,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_normBoxplot.png',
#   'restricted': False,
#   'subcategory': 'Normalized Data',
#   'subdirectory': 'Plots and Images',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096719.936,
#   'date_updated': 1582096719.936,
#   'file_name': 'GLDS-87_array_Mmus_C57-6CR_RTN_GC_Rep2_18R_raw.CEL.gz',
#   'file_size': 6359489,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_Mmus_C57-6CR_RTN_GC_Rep2_18R_raw.CEL.gz',
#   'restricted': False,
#   'subcategory': 'Raw Data',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096913.974,
#   'date_updated': 1582096913.974,
#   'file_name': 'GLDS-87_array_normPCA.png',
#   'file_size': 27913,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_normPCA.png',
#   'restricted': False,
#   'subcategory': 'Normalized Data',
#   'subdirectory': 'Plots and Images',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096842.583,
#   'date_updated': 1582096842.583,
#   'file_name': 'GLDS-87_array_differential_expression.csv',
#   'file_size': 13406885,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_differential_expression.csv',
#   'restricted': False,
#   'subcategory': 'Differential Expression Analyses',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096720.236,
#   'date_updated': 1582096720.236,
#   'file_name': 'GLDS-87_array_Mmus_C57-6CR_RTN_GC_Rep3_20R_raw.CEL.gz',
#   'file_size': 6483811,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_Mmus_C57-6CR_RTN_GC_Rep3_20R_raw.CEL.gz',
#   'restricted': False,
#   'subcategory': 'Raw Data',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096720.165,
#   'date_updated': 1582096720.165,
#   'file_name': 'GLDS-87_array_Mmus_C57-6CR_RTN_FLT_Rep1_52R_raw.CEL.gz',
#   'file_size': 6379831,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_Mmus_C57-6CR_RTN_FLT_Rep1_52R_raw.CEL.gz',
#   'restricted': False,
#   'subcategory': 'Raw Data',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096720.118,
#   'date_updated': 1582096720.118,
#   'file_name': 'GLDS-87_array_Mmus_C57-6CR_RTN_GC_Rep1_16R_raw.CEL.gz',
#   'file_size': 6463871,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_Mmus_C57-6CR_RTN_GC_Rep1_16R_raw.CEL.gz',
#   'restricted': False,
#   'subcategory': 'Raw Data',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096720.619,
#   'date_updated': 1582096720.619,
#   'file_name': 'GLDS-87_array_Mmus_C57-6CR_RTN_FLT_Rep3_58R_raw.CEL.gz',
#   'file_size': 6413259,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_Mmus_C57-6CR_RTN_FLT_Rep3_58R_raw.CEL.gz',
#   'restricted': False,
#   'subcategory': 'Raw Data',
#   'subdirectory': '',
#   'visible': True},
#  {'category': 'GeneLab Processed Microarray Data Files',
#   'date_created': 1582096720.185,
#   'date_updated': 1582096720.185,
#   'file_name': 'GLDS-87_array_Mmus_C57-6CR_RTN_FLT_Rep2_54R_raw.CEL.gz',
#   'file_size': 6083294,
#   'organization': 'genelab',
#   'remote_url': '/geode-py/ws/studies/OSD-87/download?source=datamanager&file=GLDS-87_array_Mmus_C57-6CR_RTN_FLT_Rep2_54R_raw.CEL.gz',
#   'restricted': False,
#   'subcategory': 'Raw Data',
#   'subdirectory': '',
#   'visible': True}]
# Archive:  data/OSD-87/GLDS-87_metadata_Zanello_STS135-ISA.zip
#   inflating: data/OSD-87/metadata/s_Zanello.txt
#   inflating: data/OSD-87/metadata/a_zanello_transcription_profiling_DNA_microarray.txt
#   inflating: data/OSD-87/metadata/i_Investigation.txt
